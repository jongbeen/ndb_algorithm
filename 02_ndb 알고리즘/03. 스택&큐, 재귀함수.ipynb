# %% [markdown]
# ### 스택 구현 예제
# ![image.png](attachment:image.png)

# %%
a = [1,2,3,4]
a[::-1]
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# ### 큐 구현 예제
# ![image.png](attachment:image.png)
# - deque 라이브러리를 통해 popleft()메소드를 사용한다
# - pop(0)의 경우 원소를 꺼내면서 index를 조절하기 때문에 O(K) 시간 복잡도를 가진다.
# - 하지만 popleft()의 경우 하나의 데이터만 뽑으므로 O(1)만큼의 시간 복잡도를 가진다

# %% [markdown]
# ### 재귀 함수
# ![image.png](attachment:image.png)
# - DFS를 사용하기 위해 필요한 재귀함수
# - 문제 풀이에 사용할 때는 반드시 종료조건을 명시해야 한다.

# %% [markdown]
# ![image.png](attachment:image.png)
# - 유클리드 호제법을 이용해서,4번의 반복과정을 통해 최대공약수(GCD)를 구할 수 있음

# %% [markdown]
# #### 유클리드 호제법 재귀함수 구현
# ![image.png](attachment:image.png)

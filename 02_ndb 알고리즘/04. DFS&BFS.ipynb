# %% [markdown]
# ### DFS 그래프
# ![image.png](attachment:image.png)

# %% [markdown]
# #### DFS 소스코드
# ![image.png](attachment:image.png)
# - index 0은 사용하지 않으므로 하나 더 큰 index가짐

# %%
def DFS(graph, v, visited):
    visited[v] = True
    print(v, end=' ')
    for i in graph[v]:
        if not visited[i]:
            DFS(graph, i, visited)

graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]
visited = [False] * 9
DFS(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %% [markdown]
# ### BFS 그래프
# ![image.png](attachment:image.png)
# - 먼저 노드1을 넣고, 꺼내면서 인접노드를 넣는다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### BFS 소스코드
# ![image.png](attachment:image.png)

# %%
from collections import deque

def BFS(graph, start):
    queue = deque([start])
    visited = [False] * 9
    visited[start] = True
    while queue:
        v = queue.popleft()
        print(v, end=' ')
        
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True
                
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]
BFS(graph, 1)
# Out:
# 1 2 3 8 7 4 5 6

# %% [markdown]
# #### 문제 1. 얼음 얼려먹기
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 내 답

# %%
from collections import deque

dx = [0,0,-1,1]
dy = [-1,1,0,0]

def BFS(graph,i,j):
    visited[i][j] = True
    queue = deque([(i,j)])
    while queue:
        x,y = queue.popleft()
        for nx,ny in zip(dx,dy):
            nx, ny = x+nx,y+ny
            if 0<=nx<N and 0<=ny<M:
                if not visited[nx][ny] and not graph[nx][ny]==1:
                    queue.append((nx,ny))
                    visited[nx][ny] = True
                    
N,M = map(int,input().split())
box = [[0]*M for _ in range(N)]

for i in range(N):
    box[i] = list(map(int,input()))
    
visited = [[False]*M for _ in range(N)]
count = 0

for i in range(N):
    for j in range(M):
        if not visited[i][j] and not box[i][j] == 1:
            BFS(box,i,j)
            count+=1
print(count)
# Out:
# 4 5
# 00110
# 00011
# 11111
# 00000
# 3

# %% [markdown]
# ##### 답안

# %%
def dfs(x,y):
    if x<=-1 or x>=n or y<=-1 or y>=m:
        return False
    if graph[x][y] == 0:
        graph[x][y] = 1
        
        dfs(x-1,y)
        dfs(x,y-1)
        dfs(x+1,y)
        dfs(x,y+1)
        return True
    return False

n,m = map(int, input().split())
graph = []
for i in range(n):
    graph.append(list(map,int,input()))
    
for i in range(n):
    for j in range(m):
        if dfs(i,j) == True:
            result +=1
print(result)

# %% [markdown]
# #### 문제 2. 미로 탈출
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque

dx = [0,0,-1,1]
dy = [-1,1,0,0]

def BFS(graph):
    visited = [[False]*M for _ in range(N)]
    visited[0][0] = True
    queue = deque([(0,0,1)])
    while queue:
        x,y,cnt = queue.popleft()
        if x==N-1 and y==M-1:
            return cnt
        for nx,ny in zip(dx,dy):
            nx, ny = x+nx,y+ny
            if 0<=nx<N and 0<=ny<M:
                if not visited[nx][ny] and not graph[nx][ny]==0:
                    queue.append((nx,ny,cnt+1))
                    visited[nx][ny] = True

N, M = map(int,input().split())
graph = []
for _ in range(N):
    graph.append(list(map(int,input())))
    
print(BFS(graph))
# Out:
# 5 6
# 101010
# 111111
# 000001
# 111111
# 111111
# 10

# %% [markdown]
# ##### 답안

# %%
from collections import deque

def bfs(x,y):
    queue = deque()
    queue.append((x,y))
    while queue:
        x,y = queue.popleft()
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            if nx<0 or nx>=n or ny<0 or ny>=m:
                continue
            if graph[nx][ny] == 0:
                continue
            if graph[nx][ny] == 1:
                graph[nx][ny] == graph[x][y] + 1
                queue.append((nx,ny))
                
    return graph[n-1][m-1]
n,m = map(int, input().split())
graph = []
for i in range(n):
    graph.append(list(map(int,input())))
    
dx = [0,0,-1,1]
dy = [-1,1,0,0]

print(bfs(0,0))
# Out:
# 5 6
# 101010
# 111111
# 000001
# 111111
# 111111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-accd5ec550ae> in <module>
#      26 dy = [-1,1,0,0]
#      27
# ---> 28 print(bfs(0,0))
#
# <ipython-input-37-accd5ec550ae> in bfs(x, y)
#       6     while queue:
#       7         x,y = queue.popleft()
# ----> 8         for i in range(4):
#       9             nx = x + dx[i]
#      10             ny = y + dy[i]
#
# KeyboardInterrupt:

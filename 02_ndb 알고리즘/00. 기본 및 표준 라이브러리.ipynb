# %% [markdown]
# ## 가장 많이 사용하는 라이브러리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. 순열과 조합
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1. 순열
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. 조합
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. 중복순열과 중복 조합
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Counter [등장횟수를 세는 라이브러리]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 최대 공약수와 최소 공배수 (math라이브러리)
# ![image.png](attachment:image.png)
